# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
## Data structures:

xvalues = np.arange(0.0, 3*3.14159265, 0.01)

#xvalues

# %%
# Here is another list, which we get using 
# a 'list comprehsion'

import math

yvalues = np.sin(xvalues)

#yvalues

# %%
# Let's apply a function to a this list:

plt.plot(xvalues, yvalues)

# %%
import matplotlib.pyplot as plt

plt.plot(xvalues, yvalues)

# %%
plt.show()

# %%
# EXERCISES:
# 1. Plot this function over two full periods
# 2. Plot the function exp(-0.2*x)*sin(5*x) over [0, 3pi]

# %%
yvalues = np.exp(-0.4*xvalues)*np.sin(5*xvalues)

# %%
plt.plot(xvalues, yvalues)

# %%
plt.show()
