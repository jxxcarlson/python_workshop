# %%
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14598.3]

# %%
import matplotlib.pyplot as plt

plt.plot(years, gdp, color='green', marker='o', linestyle='solid')
plt.title("Nominal GDP")
plt.ylabel("Billions of $")
plt.savefig("gdp.png")
plt.show()

# %%
import pandas as pd
df = pd.read_csv('gdp.csv')
print "shape =", df.shape
# Out:
#  shape = (11507, 4)

# %%
usa_gdp = df[df['Country Code'] == 'USA']
usa_gdp.tail()
# Out:
#         Country Name Country Code  Year         Value
# 11081  United States          USA  2012  1.615526e+13
# 11082  United States          USA  2013  1.669152e+13
# 11083  United States          USA  2014  1.739310e+13
# 11084  United States          USA  2015  1.812071e+13
# 11085  United States          USA  2016  1.862448e+13

# %%
usa_gdp['Value']
# Out:
# 11029    5.433000e+11
# 11030    5.633000e+11
# 11031    6.051000e+11
# 11032    6.386000e+11
# 11033    6.858000e+11
# 11034    7.437000e+11
# 11035    8.150000e+11
# 11036    8.617000e+11
# 11037    9.425000e+11
# 11038    1.019900e+12
# 11039    1.075884e+12
# 11040    1.167770e+12
# 11041    1.282449e+12
# 11042    1.428549e+12
# 11043    1.548825e+12
# 11044    1.688923e+12
# 11045    1.877587e+12
# 11046    2.085951e+12
# 11047    2.356571e+12
# 11048    2.632143e+12
# 11049    2.862505e+12
# 11050    3.210956e+12
# 11051    3.344991e+12
# 11052    3.638137e+12
# 11053    4.040693e+12
# 11054    4.346734e+12
# 11055    4.590155e+12
# 11056    4.870217e+12
# 11057    5.252629e+12
# 11058    5.657693e+12
# 11059    5.979589e+12
# 11060    6.174043e+12
# 11061    6.539299e+12
# 11062    6.878718e+12
# 11063    7.308755e+12
# 11064    7.664060e+12
# 11065    8.100201e+12
# 11066    8.608515e+12
# 11067    9.089168e+12
# 11068    9.660624e+12
# 11069    1.028478e+13
# ...

# %%
years = usa_gdp['Year'].values
usa_gdps = usa_gdp['Value'].values

# %%
usa_gdps
# Out:
# array([  5.43300000e+11,   5.63300000e+11,   6.05100000e+11,
#          6.38600000e+11,   6.85800000e+11,   7.43700000e+11,
#          8.15000000e+11,   8.61700000e+11,   9.42500000e+11,
#          1.01990000e+12,   1.07588400e+12,   1.16777000e+12,
#          1.28244900e+12,   1.42854900e+12,   1.54882500e+12,
#          1.68892300e+12,   1.87758700e+12,   2.08595100e+12,
#          2.35657100e+12,   2.63214300e+12,   2.86250500e+12,
#          3.21095600e+12,   3.34499100e+12,   3.63813700e+12,
#          4.04069300e+12,   4.34673400e+12,   4.59015500e+12,
#          4.87021700e+12,   5.25262900e+12,   5.65769300e+12,
#          5.97958900e+12,   6.17404300e+12,   6.53929900e+12,
#          6.87871800e+12,   7.30875500e+12,   7.66406000e+12,
#          8.10020100e+12,   8.60851500e+12,   9.08916800e+12,
#          9.66062400e+12,   1.02847790e+13,   1.06218240e+13,
#          1.09775140e+13,   1.15106700e+13,   1.22749280e+13,
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(years, usa_gdps)
plt.show()

# %%
gb_gdp = df[df['Country Code'] == 'GBR']
gb_gdp
# Out:
#          Country Name Country Code  Year         Value
# 10972  United Kingdom          GBR  1960  7.232805e+10
# 10973  United Kingdom          GBR  1961  7.669436e+10
# 10974  United Kingdom          GBR  1962  8.060194e+10
# 10975  United Kingdom          GBR  1963  8.544377e+10
# 10976  United Kingdom          GBR  1964  9.338760e+10
# 10977  United Kingdom          GBR  1965  1.005958e+11
# 10978  United Kingdom          GBR  1966  1.070907e+11
# 10979  United Kingdom          GBR  1967  1.111854e+11
# 10980  United Kingdom          GBR  1968  1.047027e+11
# 10981  United Kingdom          GBR  1969  1.126769e+11
# 10982  United Kingdom          GBR  1970  1.306719e+11
# 10983  United Kingdom          GBR  1971  1.481139e+11
# 10984  United Kingdom          GBR  1972  1.699650e+11
# 10985  United Kingdom          GBR  1973  1.925380e+11
# 10986  United Kingdom          GBR  1974  2.061314e+11
# 10987  United Kingdom          GBR  1975  2.417566e+11
# ...

# %%
gb_gdps = gb_gdp['Value'].values

# %%
plt.plot(years, gb_gdps)
#plt.plot(years, usa_gdps)

# %%
plt.show()
